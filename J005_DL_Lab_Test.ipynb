# %% [markdown]
# <a href="https://colab.research.google.com/github/harshbhabhera/Deep-Learning/blob/master/J005_DL_Lab_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import os
import random
import zipfile
import shutil  
import urllib.request
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.utils.np_utils import to_categorical
from keras import models
from keras.datasets import cifar10
from keras.layers import Dense, Dropout
from keras.models import Sequential
from keras.layers import Activation, Flatten, Conv2D
from keras.utils import to_categorical
from keras.datasets import mnist
from keras.utils.vis_utils import model_to_dot
from IPython.display import SVG
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
url = "http://weegee.vision.ucmerced.edu/datasets/UCMerced_LandUse.zip"
urllib.request.urlretrieve(url, 'dataset.zip')

with zipfile.ZipFile("/content/dataset.zip","r") as zip_ref:
    zip_ref.extractall("data")

# %%
train_path ='/content/data/UCMerced_LandUse/Images'
os.mkdir('/content/data/UCMerced_LandUse/test')
os.mkdir('/content/data/UCMerced_LandUse/validation')
validation_path = '/content/data/UCMerced_LandUse/validation'
test_path  = '/content/data/UCMerced_LandUse/test'

train_folders = os.listdir(train_path)
validation_folders = os.listdir(validation_path)
test_folders = os.listdir(test_path)

# %%
for folder in train_folders:
    if folder != ".DS_Store":
        current_path = os.path.join(train_path,folder)
        files = os.listdir(current_path)
        files_to_move = files[-15:]
        v_destination = (os.path.join(validation_path, folder))
        t_destination = (os.path.join(test_path, folder))

        file_counter = 0
        for file in files_to_move:
            if file_counter <= 10:
              source = os.path.join(current_path,file)
              print(source)
              if os.path.exists(v_destination):
                dest = shutil.copy(source, v_destination)
                os.remove(source)
                print(source, "moved to" , v_destination)
                file_counter = file_counter + 1
              else:
                os.mkdir(v_destination)
                dest = shutil.copy(source, v_destination)
                os.remove(source)
                print(source, "moved to" , v_destination)
                file_counter = file_counter + 1
            else:
              source = os.path.join(current_path,file)
              print(source)
              if os.path.exists(t_destination):
                dest = shutil.copy(source, t_destination)
                os.remove(source)
                print(source, "moved to" , t_destination)
                file_counter = file_counter + 1
              else:
                os.mkdir(t_destination)
                dest = shutil.copy(source, t_destination)
                os.remove(source)
                print(source, "moved to" , t_destination)
                file_counter = file_counter + 1
# Out:
# /content/data/UCMerced_LandUse/Images/freeway/freeway33.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway33.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway05.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway05.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway50.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway50.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway62.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway62.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway63.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway63.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway45.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway45.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway85.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway85.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway43.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway43.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway96.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway96.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway41.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway41.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway53.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway53.tif moved to /content/data/UCMerced_LandUse/validation/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway18.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway18.tif moved to /content/data/UCMerced_LandUse/test/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway12.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway12.tif moved to /content/data/UCMerced_LandUse/test/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway94.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway94.tif moved to /content/data/UCMerced_LandUse/test/freeway
# /content/data/UCMerced_LandUse/Images/freeway/freeway47.tif
# /content/data/UCMerced_LandUse/Images/freeway/freeway47.tif moved to /content/data/UCMerced_LandUse/test/freeway
# /content/data/UCMerced_LandUse/Images/airplane/airplane21.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane21.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane98.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane98.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane42.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane42.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane46.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane46.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane13.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane13.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane36.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane36.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane12.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane12.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane79.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane79.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane64.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane64.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane58.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane58.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane86.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane86.tif moved to /content/data/UCMerced_LandUse/validation/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane01.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane01.tif moved to /content/data/UCMerced_LandUse/test/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane94.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane94.tif moved to /content/data/UCMerced_LandUse/test/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane60.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane60.tif moved to /content/data/UCMerced_LandUse/test/airplane
# /content/data/UCMerced_LandUse/Images/airplane/airplane76.tif
# /content/data/UCMerced_LandUse/Images/airplane/airplane76.tif moved to /content/data/UCMerced_LandUse/test/airplane
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot00.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot00.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot56.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot56.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot11.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot11.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot78.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot78.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot21.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot21.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot09.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot09.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot53.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot53.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot64.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot64.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot35.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot35.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot99.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot99.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot30.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot30.tif moved to /content/data/UCMerced_LandUse/validation/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot80.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot80.tif moved to /content/data/UCMerced_LandUse/test/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot94.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot94.tif moved to /content/data/UCMerced_LandUse/test/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot82.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot82.tif moved to /content/data/UCMerced_LandUse/test/parkinglot
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot33.tif
# /content/data/UCMerced_LandUse/Images/parkinglot/parkinglot33.tif moved to /content/data/UCMerced_LandUse/test/parkinglot
# /content/data/UCMerced_LandUse/Images/runway/runway87.tif
# /content/data/UCMerced_LandUse/Images/runway/runway87.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway91.tif
# /content/data/UCMerced_LandUse/Images/runway/runway91.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway08.tif
# /content/data/UCMerced_LandUse/Images/runway/runway08.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway02.tif
# /content/data/UCMerced_LandUse/Images/runway/runway02.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway17.tif
# /content/data/UCMerced_LandUse/Images/runway/runway17.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway50.tif
# /content/data/UCMerced_LandUse/Images/runway/runway50.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway40.tif
# /content/data/UCMerced_LandUse/Images/runway/runway40.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway66.tif
# /content/data/UCMerced_LandUse/Images/runway/runway66.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway46.tif
# /content/data/UCMerced_LandUse/Images/runway/runway46.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway34.tif
# /content/data/UCMerced_LandUse/Images/runway/runway34.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway52.tif
# /content/data/UCMerced_LandUse/Images/runway/runway52.tif moved to /content/data/UCMerced_LandUse/validation/runway
# /content/data/UCMerced_LandUse/Images/runway/runway27.tif
# /content/data/UCMerced_LandUse/Images/runway/runway27.tif moved to /content/data/UCMerced_LandUse/test/runway
# /content/data/UCMerced_LandUse/Images/runway/runway80.tif
# /content/data/UCMerced_LandUse/Images/runway/runway80.tif moved to /content/data/UCMerced_LandUse/test/runway
# /content/data/UCMerced_LandUse/Images/runway/runway29.tif
# /content/data/UCMerced_LandUse/Images/runway/runway29.tif moved to /content/data/UCMerced_LandUse/test/runway
# /content/data/UCMerced_LandUse/Images/runway/runway98.tif
# /content/data/UCMerced_LandUse/Images/runway/runway98.tif moved to /content/data/UCMerced_LandUse/test/runway
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse49.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse49.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse62.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse62.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse75.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse75.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse99.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse99.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse03.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse03.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse21.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse21.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse55.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse55.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse85.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse85.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse31.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse31.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse54.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse54.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse78.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse78.tif moved to /content/data/UCMerced_LandUse/validation/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse79.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse79.tif moved to /content/data/UCMerced_LandUse/test/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse73.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse73.tif moved to /content/data/UCMerced_LandUse/test/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse28.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse28.tif moved to /content/data/UCMerced_LandUse/test/golfcourse
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse90.tif
# /content/data/UCMerced_LandUse/Images/golfcourse/golfcourse90.tif moved to /content/data/UCMerced_LandUse/test/golfcourse
# /content/data/UCMerced_LandUse/Images/forest/forest62.tif
# /content/data/UCMerced_LandUse/Images/forest/forest62.tif moved to /content/data/UCMerced_LandUse/validation/forest
# /content/data/UCMerced_LandUse/Images/forest/forest66.tif
# /content/data/UCMerced_LandUse/Images/forest/forest66.tif moved to /content/data/UCMerced_LandUse/validation/forest
# /content/data/UCMerced_LandUse/Images/forest/forest95.tif
# /content/data/UCMerced_LandUse/Images/forest/forest95.tif moved to /content/data/UCMerced_LandUse/validation/forest
# /content/data/UCMerced_LandUse/Images/forest/forest45.tif
# /content/data/UCMerced_LandUse/Images/forest/forest45.tif moved to /content/data/UCMerced_LandUse/validation/forest
# /content/data/UCMerced_LandUse/Images/forest/forest85.tif
# /content/data/UCMerced_LandUse/Images/forest/forest85.tif moved to /content/data/UCMerced_LandUse/validation/forest
# /content/data/UCMerced_LandUse/Images/forest/for
tif
# /content/data/UCMerced_LandUse/Images/agricultural/agricultural99.tif moved to /content/data/UCMerced_LandUse/test/agricultural
# /content/data/UCMerced_LandUse/Images/agricultural/agricultural29.tif
# /content/data/UCMerced_LandUse/Images/agricultural/agricultural29.tif moved to /content/data/UCMerced_LandUse/test/agricultural
# /content/data/UCMerced_LandUse/Images/agricultural/agricultural40.tif
# /content/data/UCMerced_LandUse/Images/agricultural/agricultural40.tif moved to /content/data/UCMerced_LandUse/test/agricultural
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond12.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond12.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond19.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond19.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond42.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond42.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond06.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond06.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond29.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond29.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond23.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond23.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond14.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond14.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond04.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond04.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond90.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond90.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond35.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond35.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond63.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond63.tif moved to /content/data/UCMerced_LandUse/validation/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond10.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond10.tif moved to /content/data/UCMerced_LandUse/test/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond32.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond32.tif moved to /content/data/UCMerced_LandUse/test/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond49.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond49.tif moved to /content/data/UCMerced_LandUse/test/baseballdiamond
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond76.tif
# /content/data/UCMerced_LandUse/Images/baseballdiamond/baseballdiamond76.tif moved to /content/data/UCMerced_LandUse/test/baseballdiamond
# /content/data/UCMerced_LandUse/Images/harbor/harbor95.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor95.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor77.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor77.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor64.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor64.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor50.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor50.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor93.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor93.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor10.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor10.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor34.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor34.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor76.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor76.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor63.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor63.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor41.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor41.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor38.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor38.tif moved to /content/data/UCMerced_LandUse/validation/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor04.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor04.tif moved to /content/data/UCMerced_LandUse/test/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor81.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor81.tif moved to /content/data/UCMerced_LandUse/test/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor13.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor13.tif moved to /content/data/UCMerced_LandUse/test/harbor
# /content/data/UCMerced_LandUse/Images/harbor/harbor06.tif
# /content/data/UCMerced_LandUse/Images/harbor/harbor06.tif moved to /content/data/UCMerced_LandUse/test/harbor
# /content/data/UCMerced_LandUse/Images/river/river34.tif
# /content/data/UCMerced_LandUse/Images/river/river34.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river01.tif
# /content/data/UCMerced_LandUse/Images/river/river01.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river06.tif
# /content/data/UCMerced_LandUse/Images/river/river06.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river94.tif
# /content/data/UCMerced_LandUse/Images/river/river94.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river60.tif
# /content/data/UCMerced_LandUse/Images/river/river60.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river89.tif
# /content/data/UCMerced_LandUse/Images/river/river89.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river53.tif
# /content/data/UCMerced_LandUse/Images/river/river53.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river67.tif
# /content/data/UCMerced_LandUse/Images/river/river67.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river36.tif
# /content/data/UCMerced_LandUse/Images/river/river36.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river07.tif
# /content/data/UCMerced_LandUse/Images/river/river07.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river29.tif
# /content/data/UCMerced_LandUse/Images/river/river29.tif moved to /content/data/UCMerced_LandUse/validation/river
# /content/data/UCMerced_LandUse/Images/river/river61.tif
# /content/data/UCMerced_LandUse/Images/river/river61.tif moved to /content/data/UCMerced_LandUse/test/river
# /content/data/UCMerced_LandUse/Images/river/river69.tif
# /content/data/UCMerced_LandUse/Images/river/river69.tif moved to /content/data/UCMerced_LandUse/test/river
# /content/data/UCMerced_LandUse/Images/river/river98.tif
# /content/data/UCMerced_LandUse/Images/river/river98.tif moved to /content/data/UCMerced_LandUse/test/river
# /content/data/UCMerced_LandUse/Images/river/river02.tif
# /content/data/UCMerced_LandUse/Images/river/river02.tif moved to /content/data/UCMerced_LandUse/test/river
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks66.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks66.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks76.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks76.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks14.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks14.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks94.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks94.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks80.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks80.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks21.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks21.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks61.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks61.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks08.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks08.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks52.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks52.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks86.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks86.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks28.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks28.tif moved to /content/data/UCMerced_LandUse/validation/storagetanks
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetanks13.tif
# /content/data/UCMerced_LandUse/Images/storagetanks/storagetan
tif
# /content/data/UCMerced_LandUse/Images/buildings/buildings19.tif moved to /content/data/UCMerced_LandUse/test/buildings
# /content/data/UCMerced_LandUse/Images/buildings/buildings14.tif
# /content/data/UCMerced_LandUse/Images/buildings/buildings14.tif moved to /content/data/UCMerced_LandUse/test/buildings
# /content/data/UCMerced_LandUse/Images/buildings/buildings98.tif
# /content/data/UCMerced_LandUse/Images/buildings/buildings98.tif moved to /content/data/UCMerced_LandUse/test/buildings
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral36.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral36.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral27.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral27.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral53.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral53.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral61.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral61.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral21.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral21.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral71.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral71.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral17.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral17.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral58.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral58.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral38.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral38.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral95.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral95.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral97.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral97.tif moved to /content/data/UCMerced_LandUse/validation/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral47.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral47.tif moved to /content/data/UCMerced_LandUse/test/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral34.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral34.tif moved to /content/data/UCMerced_LandUse/test/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral54.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral54.tif moved to /content/data/UCMerced_LandUse/test/chaparral
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral40.tif
# /content/data/UCMerced_LandUse/Images/chaparral/chaparral40.tif moved to /content/data/UCMerced_LandUse/test/chaparral
# /content/data/UCMerced_LandUse/Images/beach/beach66.tif
# /content/data/UCMerced_LandUse/Images/beach/beach66.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach89.tif
# /content/data/UCMerced_LandUse/Images/beach/beach89.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach54.tif
# /content/data/UCMerced_LandUse/Images/beach/beach54.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach74.tif
# /content/data/UCMerced_LandUse/Images/beach/beach74.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach62.tif
# /content/data/UCMerced_LandUse/Images/beach/beach62.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach71.tif
# /content/data/UCMerced_LandUse/Images/beach/beach71.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach28.tif
# /content/data/UCMerced_LandUse/Images/beach/beach28.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach70.tif
# /content/data/UCMerced_LandUse/Images/beach/beach70.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach37.tif
# /content/data/UCMerced_LandUse/Images/beach/beach37.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach32.tif
# /content/data/UCMerced_LandUse/Images/beach/beach32.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach47.tif
# /content/data/UCMerced_LandUse/Images/beach/beach47.tif moved to /content/data/UCMerced_LandUse/validation/beach
# /content/data/UCMerced_LandUse/Images/beach/beach17.tif
# /content/data/UCMerced_LandUse/Images/beach/beach17.tif moved to /content/data/UCMerced_LandUse/test/beach
# /content/data/UCMerced_LandUse/Images/beach/beach92.tif
# /content/data/UCMerced_LandUse/Images/beach/beach92.tif moved to /content/data/UCMerced_LandUse/test/beach
# /content/data/UCMerced_LandUse/Images/beach/beach77.tif
# /content/data/UCMerced_LandUse/Images/beach/beach77.tif moved to /content/data/UCMerced_LandUse/test/beach
# /content/data/UCMerced_LandUse/Images/beach/beach31.tif
# /content/data/UCMerced_LandUse/Images/beach/beach31.tif moved to /content/data/UCMerced_LandUse/test/beach

# %%
# Path to the train folder
original_test = '/content/data/UCMerced_LandUse/test'
categories = os.listdir(original_test)
files_list = []
categories_list = []
for category in categories:
   category_path = os.path.join(original_test,category)

   files = os.listdir(category_path)
   for file_name in files:
     files_list.append(str(category) + "/" + file_name)
     categories_list.append(category)

print(len(files_list))
print(len(categories_list))
data_test = pd.DataFrame({'filename':files_list,'label':categories_list})

data_test.to_csv("original_test.csv",index=False)
# Out:
# 84
# 84

# %% [markdown]
# Here data augmentation is used.
# The below cell is also serving the purpose of creating data generator which will later be fed into the model

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)



train_generator = train_datagen.flow_from_directory(
    directory=r"/content/data/UCMerced_LandUse/Images",
    target_size=(70, 70),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

valid_generator = test_datagen.flow_from_directory(
    directory=r"/content/data/UCMerced_LandUse/validation",
    target_size=(70, 70),
    color_mode="rgb",
    batch_size=32,
    class_mode="categorical",
    shuffle=True,
    seed=42
)

test_generator = test_datagen.flow_from_directory(
    directory="/content/data/UCMerced_LandUse/test",
    target_size=(70, 70),
    color_mode="rgb",
    batch_size=1,
    class_mode=None,
    shuffle=False,
    seed=42
)
# Out:
# Found 1785 images belonging to 21 classes.
# Found 231 images belonging to 21 classes.
# Found 84 images belonging to 21 classes.

# %% [markdown]
# The hyper parameters in this model are the default values.
# convolutional layes contain 32 nodes having a filter of (3,3)
# Learning rate is default (0.01)
# The loss is categorical crossentropy
# The optimizer used is adam

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size


model = Sequential() #model = sequential 
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',input_shape=(70,70,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten()) #make layer flatten
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(21, activation='softmax'))

model.compile(loss='categorical_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.

# %% [markdown]
# Model Summary

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 68, 68, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 34, 34, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 32)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1568)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               200832
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 21)                2709
# =================================================================
# Total params: 222,933
# Trainable params: 222,933
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# loss vs epochs and accuracy vs epochs - on train and validation

# %%
model.fit_generator(generator=train_generator,
                    steps_per_epoch=STEP_SIZE_TRAIN,
                    validation_data=valid_generator,
                    validation_steps=STEP_SIZE_VALID,
                    epochs=25)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/25
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 55/55 [==============================] - 18s 321ms/step - loss: 3.0173 - acc: 0.0614 - val_loss: 2.9481 - val_acc: 0.0848
# Epoch 2/25
# 55/55 [==============================] - 4s 74ms/step - loss: 2.8318 - acc: 0.1117 - val_loss: 2.7378 - val_acc: 0.1608
# Epoch 3/25
# 55/55 [==============================] - 4s 72ms/step - loss: 2.6332 - acc: 0.1682 - val_loss: 2.6172 - val_acc: 0.2111
# Epoch 4/25
# 55/55 [==============================] - 4s 72ms/step - loss: 2.4760 - acc: 0.2260 - val_loss: 2.3765 - val_acc: 0.2663
# Epoch 5/25
# 55/55 [==============================] - 4s 72ms/step - loss: 2.2172 - acc: 0.2993 - val_loss: 2.0933 - val_acc: 0.3166
# Epoch 6/25
# 55/55 [==============================] - 4s 72ms/step - loss: 2.1483 - acc: 0.3132 - val_loss: 1.8250 - val_acc: 0.3568
# Epoch 7/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.9081 - acc: 0.3690 - val_loss: 1.9820 - val_acc: 0.3819
# Epoch 8/25
# 55/55 [==============================] - 4s 73ms/step - loss: 1.8315 - acc: 0.4096 - val_loss: 1.7888 - val_acc: 0.4472
# Epoch 9/25
# 55/55 [==============================] - 4s 73ms/step - loss: 1.6857 - acc: 0.4608 - val_loss: 2.1030 - val_acc: 0.4018
# Epoch 10/25
# 55/55 [==============================] - 4s 77ms/step - loss: 1.6561 - acc: 0.4728 - val_loss: 2.1612 - val_acc: 0.3970
# Epoch 11/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.5113 - acc: 0.5262 - val_loss: 1.4526 - val_acc: 0.5427
# Epoch 12/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.4550 - acc: 0.5234 - val_loss: 1.2863 - val_acc: 0.6030
# Epoch 13/25
# 55/55 [==============================] - 4s 74ms/step - loss: 1.3823 - acc: 0.5445 - val_loss: 1.5996 - val_acc: 0.4975
# Epoch 14/25
# 55/55 [==============================] - 4s 74ms/step - loss: 1.3505 - acc: 0.5473 - val_loss: 1.3707 - val_acc: 0.5628
# Epoch 15/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.2516 - acc: 0.5727 - val_loss: 1.1549 - val_acc: 0.6432
# Epoch 16/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.1976 - acc: 0.6083 - val_loss: 1.2202 - val_acc: 0.6181
# Epoch 17/25
# 55/55 [==============================] - 4s 74ms/step - loss: 1.1481 - acc: 0.6267 - val_loss: 1.1328 - val_acc: 0.6339
# Epoch 18/25
# 55/55 [==============================] - 4s 75ms/step - loss: 1.1969 - acc: 0.6077 - val_loss: 1.3381 - val_acc: 0.5578
# Epoch 19/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.1507 - acc: 0.6261 - val_loss: 1.2889 - val_acc: 0.5729
# Epoch 20/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.1033 - acc: 0.6308 - val_loss: 1.2681 - val_acc: 0.6131
# Epoch 21/25
# 55/55 [==============================] - 4s 72ms/step - loss: 1.0550 - acc: 0.6571 - val_loss: 1.0962 - val_acc: 0.6332
# Epoch 22/25
# 55/55 [==============================] - 4s 72ms/step - loss: 0.9958 - acc: 0.6684 - val_loss: 0.9657 - val_acc: 0.7035
# Epoch 23/25
# 55/55 [==============================] - 4s 72ms/step - loss: 0.9544 - acc: 0.6839 - val_loss: 1.3686 - val_acc: 0.5528
# Epoch 24/25
# 55/55 [==============================] - 4s 71ms/step - loss: 0.9396 - acc: 0.6972 - val_loss: 1.0629 - val_acc: 0.6482
# Epoch 25/25
# 55/55 [==============================] - 4s 74ms/step - loss: 0.9300 - acc: 0.7009 - val_loss: 1.2671 - val_acc: 0.5759

# %% [markdown]
# Making Predictions on the Test Set

# %%
import pandas as pd

STEP_SIZE_TEST=test_generator.n//test_generator.batch_size
test_generator.reset()
pred=model.predict_generator(test_generator,
steps=STEP_SIZE_TEST,
verbose=1)

predicted_class_indices = []
for i in pred:
        predicted_class_indices.append(np.argmax(np.asarray(i)))

labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
results.to_csv("results.csv",index=False)
# Out:
# 84/84 [==============================] - 0s 3ms/step

# %% [markdown]
# Creating a Final Dataframe which contains the test file names, the actual label and the predicted label

# %%
final_pred_df = pd.DataFrame(columns = ["filename", "label","pred"])
filename_list = []
label_list = []
pred_list = []

for filename in results["Filename"]:
  # print(filename)
  filename_list.append(filename)
  label_list.append(data_test[data_test["filename"] == filename]["label"].values[0])
  pred_list.append(results[results["Filename"] == filename]["Predictions"].values[0])

final_pred_df["filename"] = filename_list
final_pred_df["label"] = label_list
final_pred_df["pred"] = pred_list
final_pred_df.to_csv("final.csv")

# %% [markdown]
# Creating the confusion Matrix

# %%
cm=confusion_matrix(final_pred_df['label'],final_pred_df['pred'])
sn.set(font_scale=1.4) # for label size
sn.heatmap(cm, annot=True, annot_kws={"size": 16}) # font size

plt.show()

# %%
#Thankyou so much!
